# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
NN_dict = {2: [(["rocket", "flight"], 98),
  (["rocket", "amp"], 92),
  (["rocket", "falcon"], 128),
  (["rocket", "launch"], 99),
  (["car", "model"], 151),
  (["car", "tesla"], 203),
  (["car", "amp"], 140),
  (["model", "performance"], 90),
  (["model", "review"], 83),
  (["model", "tesla"], 183),
  (["model", "amp"], 93),
  (["model", "production"], 124),
  (["space", "station"], 185),
  (["space", "dragon"], 93),
  (["station", "dragon"], 93),
  (["year", "tesla"], 96),
  (["year", "end"], 90),
  (["tesla", "amp"], 201),
  (["tesla", "team"], 151),
  (["tesla", "time"], 89),
  (["tesla", "software"], 87),
  (["climate", "change"], 123),
  (["amp", "time"], 76),
  (["amp", "production"], 92),
  (["pack", "battery"], 82)],
 3: [(["space", "station", "dragon"], 90)]}

# %%
NN_dict[3]
# Out:
# [(['space', 'station', 'dragon'], 90)]

# %%
for k in range(2, 4):
    xs = ["+".join(t[0]) for t in NN_dict[k]]
    ys = [t[1] for t in NN_dict[k]]
    #bins = max(ys) - min(ys) + 1
    label = "k=" + str(k)
    plt.barh(xs, ys, label=label)

plt.title('NN Apriori')
plt.xlabel('support')
plt.legend()

# %%
VB_dict = {2: [(["get", "dont"], 12),
  (["get", "buy"], 8),
  (["get", "make"], 11),
  (["disagree", "seem"], 8),
  (["move", "figure"], 8),
  (["know", "let"], 13),
  (["love", "make"], 8),
  (["let", "decide"], 10),
  (["refer", "remember"], 8),
  (["help", "syria"], 8),
  (["need", "increase"], 8)]}

# %%
for k in range(2, 3):
    xs = ["+".join(t[0]) for t in VB_dict[k]]
    ys = [t[1] for t in VB_dict[k]]
    #bins = max(ys) - min(ys) + 1
    label = "k=" + str(k)
    plt.barh(xs, ys, label=label)
    
plt.title('VB Apriori')
plt.xlabel('support')
plt.legend()

# %%
ao_dict = {2 : [(["model", "tesla"], 346),
  (["car", "tesla"], 329),
  (["car", "amp"], 274),
  (["soon", "coming"], 263),
  (["tesla", "amp"], 729)]}

# %%
for k in range(2, 3):
    xs = ["+".join(t[0]) for t in ao_dict[k]]
    ys = [t[1] for t in ao_dict[k]]
    #bins = max(ys) - min(ys) + 1
    label = "k=" + str(k)
    plt.barh(xs, ys, label=label)
    
plt.title('Apriori')
plt.xlabel('support')
plt.legend()
