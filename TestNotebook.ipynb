# %%
from requests_oauthlib import OAuth1Session
import requests
import os
import json
import pandas as pd

# %%
# @fr16nb's token
bearer_token = "AAAAAAAAAAAAAAAAAAAAAKEUhgEAAAAAYo%2FYh5Jpb%2Fau8yaOs%2BO1bojGfFY%3DjkemdnofEolHLUwEzS7STSxqbrheB3FwKlldyCPHia9bF4tUcU"

# @TwitterDev's ID
user_id = 44196397

ids = "ids=1582379931983499264"
# tweet_fields = "tweet.fields=lang,author_id, conversation_id, created_at, entities, id, in_reply_to_user_id, source, text, withheld"
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld

# %%
def create_url():
    # Replace with user ID below
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)
    # url = "https://api.twitter.com/2/tweets?{}".format(ids)
    
    return url

# %%
  def get_params():
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    return {"tweet.fields": "conversation_id,author_id,in_reply_to_user_id,referenced_tweets,created_at,lang,text,entities,id,source,withheld",
            "expansions" : "author_id,in_reply_to_user_id,referenced_tweets.id", 
            "user.fields" : "name,username"}

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2UserTweetsPython"
    return r

# %%
# Fetchs 
def connect_to_endpoint(url, params):
    response = requests.request("GET", url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()

# %%
url = create_url()
params = get_params()
json_response = connect_to_endpoint(url, params)
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584764977457397760",
#             "created_at": "2022-10-25T13:54:37.000Z",
#             "edit_history_tweet_ids": [
#                 "1584906280082219009"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 8,
#                         "id": "14084713",
#                         "start": 0,
#                         "username": "chazman"
#                     },
#                     {
#                         "end": 20,
#                         "id": "427089628",
#                         "start": 9,
#                         "username": "lexfridman"
#                     }
#                 ]
#             },
#             "id": "1584906280082219009",
#             "in_reply_to_user_id": "14084713",
#             "lang": "en",
#             "referenced_tweets": [
#                 {
#                     "id": "1584855317833478144",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@chazman @lexfridman Fasting rocks"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584625378253209603",
#             "created_at": "2022-10-25T13:24:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1584898685736869888"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 15,
#                         "id": "295218901",
#                         "start": 0,
#                         "username": "VitalikButerin"
#                     },
#                     {
#                         "end": 24,
#                         "id": "2178012643",
#                         "start": 16,
#                         "username": "balajis"
#                     },
#                     {
#                         "end": 40,
#                         "id": "1162798396756807680",
#                         "start": 25,
#                         "username": "zengjiajun_eth"
#                     }
#                 ]
#             },
#             "id": "1584898685736869888",
#             "in_reply_to_user_id": "295218901",
#             "lang": "en",
#             "referenced_tweets": [
#                 {
#                     "id": "1584627704825278464",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@VitalikButerin @balajis @zengjiajun_eth Had to do a double-take. This is the first non-fake Vitalik tweet I\u2019ve seen in a while."
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584626500955144192",
#             "created_at": "2022-10-25T09:16:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1584836233586348033"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 16,
#                         "id": "1355945100216573952",
#                         "start": 0,
#                         "username": "dogeofficialceo"
#                     },
#                     {
#                         "end": 28,
#                         "id": "1118594454515003393",
#                         "start": 17,
#                         "username": "DirtyTesLa"
#                     },
#                     {
#                         "end": 42,
#                         "id": "995458317634830336",
#                         "start": 29,
#                         "username": "rocobasilisk"
#                     },
#                     {
#                         "end": 55,
#                         "id": "1009716150895341568",
#                         "start": 43,
#                         "username": "SwipeWright"
#                     }
#                 ]
#             },
#             "id": "1584836233586348033",
#             "in_reply_to_user_id": "1355945100216573952",
#             "lang": "und",
#             "referenced_tweets": [
#                 {
#                     "id": "1584816465957761026",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@dogeofficialceo @DirtyTesLa @rocobasilisk @SwipeWright \ud83d\udcaf"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584640964609847296",
#             "created_at": "2022-10-25T08:30:54.000Z",
#             "edit_history_tweet_ids": [
#                 "1584824812345888768"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 12,
#                         "id": "1161703589942878208",
#                         "start": 0,
#                         "username": "garyblack00"
#                     },
#                     {
#                         "end": 27,
#                         "id": "243013409",
#                         "start": 13,
#                         "username": "SawyerMerritt"
#                     }
#                 ]
#             },
#             "id": "1584824812345888768",
#             "in_reply_to_user_id": "1161703589942878208",
#             "lang": "en",
#             "referenced_tweets": [
#                 {
#                     "id": "1584646946869780480",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@garyblack00 @SawyerMerritt One man\u2019s hedge is another man\u2019s shrub"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584723401708797952",
#             "created_at": "2022-10-25T08:19:58.000Z",
#             "edit_history_tweet_ids": [
#                 "1584822061926866944"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 11,
#                         "id": "1564277306641698817",
#                         "start": 0,
#                         "username": "muskQu0tes"
#                     }
#                 ]
#             },
#             "id": "1584822061926866944",
#             "in_reply_to_user_id": "1564277306641698817",
#             "lang": "und",
#             "referenced_tweets": [
#                 {
#                     "id": "1584723401708797952",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@muskQu0tes Yup"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584743837637160960",
#             "created_at": "2022-10-25T08:11:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1584819851226669057"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 9,
#                         "id": "39125788",
#                         "start": 0,
#                         "username": "emollick"
#                     }
#                 ]
#             },
#             "id": "1584819851226669057",
#             "in_reply_to_user_id": "39125788",
#             "lang": "en",
#             "referenced_tweets": [
#                 {
#                     "id": "1584743837637160960",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@emollick True"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584712659840008193",
#             "created_at": "2022-10-25T08:01:29.000Z",
#             "edit_history_tweet_ids": [
#                 "1584817409651007488"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 12,
#                         "id": "1412040502455717893",
#                         "start": 0,
#                         "username": "elon_wisdom"
#                     }
#                 ]
#             },
#             "id": "1584817409651007488",
#             "in_reply_to_user_id": "1412040502455717893",
#             "lang": "en",
#             "referenced_tweets": [
#                 {
#                     "id": "1584712659840008193",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@elon_wisdom Too much respect for authority inhibits innovation"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584626500955144192",
#             "created_at": "2022-10-25T07:55:19.000Z",
#             "edit_history_tweet_ids": [
#                 "1584815858878017536"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 11,
#                         "id": "1118594454515003393",
#                         "start": 0,
#                         "username": "DirtyTesLa"
#                     },
#                     {
#                         "end": 25,
#                         "id": "995458317634830336",
#                         "start": 12,
#                         "username": "rocobasilisk"
#                     },
#                     {
#                         "end": 38,
#                         "id": "1009716150895341568",
#                         "start": 26,
#                         "username": "SwipeWright"
#                     }
#                 ]
#             },
#             "id": "1584815858878017536",
#             "in_reply_to_user_id": "1118594454515003393",
#             "lang": "und",
#             "referenced_tweets": [
#                 {
#                     "id": "1584735742450102273",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@DirtyTesLa @rocobasilisk @SwipeWright \ud83d\udcaa"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584752870200463360",
#             "created_at": "2022-10-25T04:35:20.000Z",
#             "edit_history_tweet_ids": [
#                 "1584765530883633152"
#             ],
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 15,
#                         "id": "31263848",
#                         "start": 0,
#                         "username": "stevenmarkryan"
#                     },
#                     {
#                         "end": 29,
#                         "id": "45967905",
#                         "start": 16,
#                         "username": "EmmetPeppers"
#                     },
#                     {
#                         "end": 39,
#                         "id": "29893444",
#                         "start": 30,
#                         "username": "heydave7"
#                     },
#                     {
#                         "end": 54,
#                         "id": "1065249714214457345",
#                         "start": 40,
#                         "username": "TwitterSpaces"
#                     },
#                     {
#                         "end": 63,
#                         "id": "10228272",
#                         "start": 55,
#                         "username": "YouTube"
#                     }
#                 ]
#             },
#             "id": "1584765530883633152",
#             "in_reply_to_user_id": "31263848",
#             "lang": "und",
#             "referenced_tweets": [
#                 {
#                     "id": "1584762889067724800",
#                     "type": "replied_to"
#                 }
#             ],
#             "source": "Twitter for iPhone",
#             "text": "@stevenmarkryan @EmmetPeppers @heydave7 @TwitterSpaces @YouTube \ud83d\ude09"
#         },
#         {
#             "author_id": "44196397",
#             "conversation_id": "1584764977457397760",
#             "created_at": "2022-10-25T04:33:08.000Z",
#             "edit_history_tweet_ids": [
#                 "1584764977457397760"
#             ],
#             "id": "1584764977457397760",
#             "lang": "en",
#             "source": "Twitter for iPhone",
#             "text": "What lesson took you the longest to unlearn?"
#         }
#     ],
#     "includes": {
#         "tweets": [
#             {
#                 "author_id": "14084713",
#                 "conversation_id": "1584764977457397760",
#                 "created_at": "2022-10-25T10:32:07.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584855317833478144"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 11,
#                             "id": "427089628",
#                             "start": 0,
#                             "username": "lexfridman"
#                         },
#                         {
#                             "end": 21,
#                             "id": "44196397",
#                             "start": 12,
#                             "username": "elonmusk"
#                         }
#                     ]
#                 },
#                 "id": "1584855317833478144",
#                 "in_reply_to_user_id": "427089628",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584770194907746305",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter Web App",
#                 "text": "@lexfridman @elonmusk Totally agree with this from Lex.  Intermittent Fasting and, at times longer term fasting has taught me how the body was designed to work .. at first principles.. don't just read about it.. try it. Lower your carbohydrate intake, you will be amazed at how your body handles it."
#             },
#             {
#                 "author_id": "295218901",
#                 "conversation_id": "1584625378253209603",
#                 "created_at": "2022-10-24T19:27:40.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584627704825278464"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 15,
#                             "id": "1162798396756807680",
#                             "start": 0,
#                             "username": "zengjiajun_eth"
#                         },
#                         {
#                             "end": 238,
#                             "id": "2178012643",
#                             "start": 230,
#                             "username": "balajis"
#                         }
#                     ]
#                 },
#                 "id": "1584627704825278464",
#                 "in_reply_to_user_id": "1162798396756807680",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584625378253209603",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter Web App",
#                 "text": "@zengjiajun_eth \"There's a premise in Western culture that to gain something you must lose. If you're Icarus and you try to fly, you'll fly too high and melt your wings. But guess what, we fly every day, commercial air flight\"\n\n- @balajis"
#             },
#             {
#                 "author_id": "1355945100216573952",
#                 "conversation_id": "1584626500955144192",
#                 "created_at": "2022-10-25T07:57:44.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584816465957761026"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 9,
#                             "id": "44196397",
#                             "start": 0,
#                             "username": "elonmusk"
#                         },
#                         {
#                             "end": 21,
#                             "id": "1118594454515003393",
#                             "start": 10,
#                             "username": "DirtyTesLa"
#                         },
#                         {
#                             "end": 35,
#                             "id": "995458317634830336",
#                             "start": 22,
#                             "username": "rocobasilisk"
#                         },
#                         {
#                             "end": 48,
#                             "id": "1009716150895341568",
#                             "start": 36,
#                             "username": "SwipeWright"
#                         }
#                     ]
#                 },
#                 "id": "1584816465957761026",
#                 "in_reply_to_user_id": "44196397",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584815858878017536",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter for iPhone",
#                 "text": "@elonmusk @DirtyTesLa @rocobasilisk @SwipeWright Can you just make Twitter more fun please, Elon?"
#             },
#             {
#                 "author_id": "1161703589942878208",
#                 "conversation_id": "1584640964609847296",
#                 "created_at": "2022-10-24T20:44:08.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584646946869780480"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 14,
#                             "id": "243013409",
#                             "start": 0,
#                             "username": "SawyerMerritt"
#                         },
#                         {
#                             "end": 24,
#                             "id": "44196397",
#                             "start": 15,
#                             "username": "elonmusk"
#                         }
#                     ]
#                 },
#                 "id": "1584646946869780480",
#                 "in_reply_to_user_id": "243013409",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584640964609847296",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter for iPhone",
#                 "text": "@SawyerMerritt @elonmusk Hedge funds love to make up shit and get media/wire services to run it. Must work."
#             },
#             {
#                 "author_id": "1564277306641698817",
#                 "conversation_id": "1584723401708797952",
#                 "created_at": "2022-10-25T01:47:56.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584723401708797952"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 123,
#                             "id": "44196397",
#                             "start": 114,
#                             "username": "elonmusk"
#                         }
#                     ]
#                 },
#                 "id": "1584723401708797952",
#                 "lang": "en",
#                 "source": "Twitter for iPhone",
#                 "text": "\"If the alarming collapse in birth rate continues, civilization will indeed die with a whimper in adult diapers.\" @elonmusk"
#             },
#             {
#                 "author_id": "39125788",
#                 "conversation_id": "1584743837637160960",
#                 "created_at": "2022-10-25T03:09:08.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584743837637160960"
#                 ],
#                 "entities": {
#                     "urls": [
#                         {
#                             "display_url": "pic.twitter.com/r0YnROh58z",
#                             "end": 311,
#                             "expanded_url": "https://twitter.com/emollick/status/1584743837637160960/photo/1",
#                             "media_key": "3_1584742331131076608",
#                             "start": 288,
#                             "url": "https://t.co/r0YnROh58z"
#                         }
#                     ]
#                 },
#                 "id": "1584743837637160960",
#                 "lang": "en",
#                 "source": "Twitter Web App",
#                 "text": "I think most people who are not playing with these technologies are way underestimating the speed of advancement in \"creative\" AIs &amp; how much of an impact that is going to have on many jobs, soon.\n\nAI language &amp; art models are growing at 10x a year. Beyond Moore's Law pacing. 1/ https://t.co/r0YnROh58z"
#             },
#             {
#                 "author_id": "1412040502455717893",
#                 "conversation_id": "1584712659840008193",
#                 "created_at": "2022-10-25T01:05:15.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584712659840008193"
#                 ],
#                 "entities": {
#                     "annotations": [
#                         {
#                             "end": 84,
#                             "normalized_text": "Elon Musk",
#                             "probability": 0.9827,
#                             "start": 76,
#                             "type": "Person"
#                         }
#                     ]
#                 },
#                 "id": "1584712659840008193",
#                 "lang": "en",
#                 "source": "Twitter for Android",
#                 "text": "\"Innovation comes from questioning the way things have been done before.\"\n\n~Elon Musk"
#             },
#             {
#                 "author_id": "1118594454515003393",
#                 "conversation_id": "1584626500955144192",
#                 "created_at": "2022-10-25T02:36:58.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584735742450102273"
#                 ],
#                 "entities": {
#                     "mentions": [
#                         {
#                             "end": 9,
#                             "id": "44196397",
#                             "start": 0,
#                             "username": "elonmusk"
#                         },
#                         {
#                             "end": 23,
#                             "id": "995458317634830336",
#                             "start": 10,
#                             "username": "rocobasilisk"
#                         },
#                         {
#                             "end": 36,
#                             "id": "1009716150895341568",
#                             "start": 24,
#                             "username": "SwipeWright"
#                         }
#                     ]
#                 },
#                 "id": "1584735742450102273",
#                 "in_reply_to_user_id": "44196397",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584715136547573762",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter Web App",
#                 "text": "@elonmusk @rocobasilisk @SwipeWright I disagree"
#             },
#             {
#                 "author_id": "31263848",
#                 "conversation_id": "1584752870200463360",
#                 "created_at": "2022-10-25T04:24:50.000Z",
#                 "edit_history_tweet_ids": [
#                     "1584762889067724800"
#                 ],
#                 "entities": {
#                     "annotations": [
#                         {
#                             "end": 82,
#                             "normalized_text": "Twitter",
#                             "probability": 0.9615,
#                             "start": 76,
#                             "type": "Other"
#                         },
#                         {
#                             "end": 122,
#                             "normalized_text": "YouTube",
#                             "probability": 0.9623,
#                             "start": 116,
#                             "type": "Other"
#                         },
#                         {
#                             "end": 166,
#                             "normalized_text": "YouTube",
#                             "probability": 0.9592,
#                             "start": 160,
#                             "type": "Other"
#                         },
#                         {
#                             "end": 183,
#                             "normalized_text": "Twitter",
#                             "probability": 0.9654,
#                             "start": 177,
#                             "type": "Other"
#                         },
#                         {
#                             "end": 267,
#                             "normalized_text": "Twitter",
#                             "probability": 0.9257,
#                             "start": 261,
#                             "type": "Other"
#                         },
#                         {
#                             "end": 276,
#                             "normalized_text": "Twitter",
#                             "probability": 0.9598,
#                             "start": 270,
#                             "type": "Other"
#                         }
#                     ],
#                     "mentions": [
#                         {
#                             "end": 13,
#                             "id": "45967905",
#                             "start": 0,
#                             "username": "EmmetPeppers"
#                         },
#                         {
#                             "end": 23,
#                             "id": "29893444",
#                             "start": 14,
#                             "username": "heydave7"
#                         },
#                         {
#                             "end": 33,
#                             "id": "44196397",
#                             "start": 24,
#                             "username": "elonmusk"
#                         },
#                         {
#                             "end": 48,
#                             "id": "1065249714214457345",
#                             "start": 34,
#                             "username": "TwitterSpaces"
#                         },
#                         {
#                             "end": 57,
#                             "id": "10228272",
#                             "start": 49,
#                             "username": "YouTube"
#                         }
#                     ]
#                 },
#                 "id": "1584762889067724800",
#                 "in_reply_to_user_id": "45967905",
#                 "lang": "en",
#                 "referenced_tweets": [
#                     {
#                         "id": "1584761205079814145",
#                         "type": "replied_to"
#                     }
#                 ],
#                 "source": "Twitter Web App",
#                 "text": "@EmmetPeppers @heydave7 @elonmusk @TwitterSpaces @YouTube It is INSANE that Twitter has not currently implemented a YouTube clone.\n\nHALF my tweets are links to YouTube videos.\n\nTwitter does not capture any value here. \n\nIf users could watch monetized videos on Twitter, Twitter would capture ad revs and massively increase \ud83d\udcb0."
#             }
#         ],
#         "users": [
#             {
#                 "id": "44196397",
#                 "name": "Elon Musk",
#                 "username": "elonmusk"
#             },
#             {
#                 "id": "14084713",
#                 "name": "Chuck Cook",
#                 "username": "chazman"
#             },
#             {
#                 "id": "295218901",
#                 "name": "vitalik.eth",
#                 "username": "VitalikButerin"
#             },
#             {
#                 "id": "1355945100216573952",
#                 "name": "Sir Doge of the Coin \u2694\ufe0f",
#                 "username": "dogeofficialceo"
#             },
#             {
#                 "id": "1161703589942878208",
#                 "name": "Gary Black",
#                 "username": "garyblack00"
#             },
#             {
#                 "id": "1564277306641698817",
#                 "name": "Elon Musk Quotes",
#                 "username": "muskQu0tes"
#             },
#             {
#                 "id": "39125788",
#                 "name": "Ethan Mollick",
#                 "username": "emollick"
#             },
#             {
#                 "id": "1412040502455717893",
#                 "name": "Elon's Wisdom",
#                 "username": "elon_wisdom"
#             },
#             {
#                 "id": "1118594454515003393",
#                 "name": "Dirty Tesla",
#                 "username": "DirtyTesLa"
#             },
#             {
#                 "id": "31263848",
#                 "name": "stevenmarkryan",
#                 "username": "stevenmarkryan"
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1584906280082219009",
#         "next_token": "7140dibdnow9c7btw423x0wl7zrix7ze1jna55q23zcq8",
#         "oldest_id": "1584764977457397760",
#         "result_count": 10
#     }
# }
